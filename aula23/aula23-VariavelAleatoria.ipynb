# %% [markdown]
# # IMD0033 - Probabilidade
#
# ## Variáveis aleatórias

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [0.1,0.2,0.3,0.4]

plt.bar(x,y)
plt.show()

# %%
y = list()
x = range(1,100)
for i in range(1,100):
    y.append(0.2*0.8**(i - 1))
    
plt.bar(x,y)
plt.show()

# %%
y = list()
x = range(1,100)
for i in range(1,100):
    prob = 1 - 0.8**(i)
    y.append(prob)
    print(prob)
    
plt.bar(x,y)
plt.show()
# Out:
# 0.19999999999999996
# 0.3599999999999999
# 0.4879999999999999
# 0.5903999999999999
# 0.6723199999999999
# 0.7378559999999998
# 0.7902847999999999
# 0.8322278399999999
# 0.8657822719999999
# 0.8926258175999999
# 0.91410065408
# 0.931280523264
# 0.9450244186112
# 0.95601953488896
# 0.9648156279111679
# 0.9718525023289344
# 0.9774820018631475
# 0.981985601490518
# 0.9855884811924144
# 0.9884707849539315
# 0.9907766279631453
# 0.9926213023705162
# 0.9940970418964129
# 0.9952776335171304
# 0.9962221068137043
# 0.9969776854509634
# 0.9975821483607707
# 0.9980657186886166
# 0.9984525749508932
# 0.9987620599607147
# 0.9990096479685717
# 0.9992077183748573
# 0.9993661746998859
# 0.9994929397599087
# 0.999594351807927
# 0.9996754814463416
# 0.9997403851570733
# 0.9997923081256586
# 0.9998338465005269
# 0.9998670772004216
# 0.9998936617603372
# 0.9999149294082698
# 0.9999319435266159
# 0.9999455548212927
# 0.9999564438570341
# 0.9999651550856273
# 0.9999721240685019
# 0.9999776992548015
# ...
